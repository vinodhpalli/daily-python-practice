# %%
#1.  Scenario: Odd or Even Duel
#Create a program that takes two numbers as input.
#Add them and determine the winner:
#If the sum is even, Player 1 wins
#If the sum is odd, Player 2 wins
a = int(input("Enter the number 1"))
b = int(input("Enter the number 2"))
total= a+b
if total % 2 == 0:
    print("Player 1 wins")
else:
    print("Player 2 wins")
# Out:
# Enter the number 1 32
# Enter the number 2 23
# Player 2 wins

# %%
#Create a program that accepts two primary colors: "red", "blue", "yellow".
#Return the secondary color formed by mixing them:
#red + blue → purple
#red + yellow → orange
#blue + yellow → green
#If both colors are the same or invalid combination, output "



a = input("Enter the colour 1 from 'red', 'blue', 'yellow'" )
b = input("Enter the colour 2 from 'red', 'blue', 'yellow'")
if a == 'red' or 'blue' and  b == 'blue' or 'red':
    print("purpule")
elif a == 'red' or 'yellow' and a ==  'yellow' or 'red':
    print("orange")
elif a == 'blue' or 'yellow' and a== 'yellow' or ;:
    print("green")
else:
    print("invalid")
# Out:
# Enter the colour 1 from 'red', 'blue', 'yellow' blue
# Enter the colour 2 from 'red', 'blue', 'yellow' red
# purpule

# %%
#3.  Scenario: Dice Roll Battle
#Create a program that simulates a dice game between two players.
#Each player rolls a number (1–6).
#The higher number wins
#If same → it's a draw
a= int(input("Enter the number from 1-6 "))
b= int(input("Enter the number from 1-6 "))
if a>b:
    print("A is higher")
elif b>a:
    print("B is higher")
elif a==b:
    print("same")
else:
    print("Invalid")
# Out:
# Enter the number from 1-6  3
# Enter the number from 1-6  4
# B is higher

# %%
#Write a program that takes a single character.
#Check if it’s a vowel (a, e, i, o, u).
#Test Cases:
#Input: a ➞ Output: Vowel
#Input: b ➞ Output: Consonant
#Input: e ➞ Output: Vowel
#Input: z ➞ Output: Consonant
a  = input("Ente the character :").lower()
vowels = 'aeiou'
if a in vowels:
    print("Vowel")
else:
    print("Consonent")
# Out:
# Ente the character : w
# Consonent

# %%
#5.  Scenario: Age Category Detector
#Create a program that takes an age and classifies it:
#<13 → Kid
#13–19 → Teen
#20–59 → Adult
#60+ → Senior
age = int(input("Enter the age:"))
if a<13:
    print("Kid")
elif age >= 13 and age <= 19:
    print("Teen")
elif age>=20 and age<=59:
    print("Adult")
else:
    print("Senior")
# Out:
# Enter the age: 67
# Senior

# %%
#6.  Scenario: Leap Year Checker
#Write a program that checks if a year is a leap year.
#A leap year is divisible by 4, but if divisible by 100, must also be divisible by 400.
y = int(input("Enter the year:"))
if y % 4 == 0:
    if y % 100 == 0:
        if y % 400 == 0:
            print("leap year")
        else:
            print("not a leap year")
    else:
        print("leap year")
else:
    print("not a leap year")
# Out:
# Enter the year: 2000
# leap year

# %%
#7.  Scenario: Word Length Game
#Create a program that accepts two words.
#Print the word with more characters.
#If both have the same length, print "Same length".
a = input(" enter the first word")
b = input(" ente the second word")
if len(a) > len(b):
    print("a has more characters")
elif len(a) < len(b):
    print("b has more characters")
else:
    print("same length")
# Out:
#  enter the first word chandu
#  ente the second word chandu
# same length

# %%
#8.  Scenario: Number Type Identifier
#Create a program that takes a number and prints:
#"Positive" if number > 0
#"Negative" if number < 0
#"Zero" if number == 0
a = int(input("Enter the number"))
if a > 0:
    print("Positive")
elif a<0:
    print("Negative")
else :
    print("Zero")
# Out:
# Enter the number 0
# Zero

# %%
#9.  Scenario: Traffic Signal Checker
#Create a program that takes a signal color and an action.
#Check if the action is valid:
#red ➞ stop
#green ➞ go
#yellow ➞ wait
a = input("Enter the colour:")
b =input("Enter thw action:")
if a == 'red' and b == 'stop':
    print("valid")
elif a== 'green' and b == 'go':
    print("valid")
elif a == 'yellow' and b == 'wait':
    print("valid")
else:
    print("invalid")
# Out:
# Enter the colour: red
# Enter thw action: go
# invalid

# %%
#0.  Scenario: Fruit Category
#Write a program that takes a fruit name and returns its category:
#Citrus: orange, lemon
#Berry: strawberry, blueberry
#Tropical: mango, pineapple
a = input("Enter the fruit name:")
citrus = " orange, lemon"
berry = "strawberry , blueberry"
tropical = " mango , pineapple"
if a in citrus:
    print("citrus")
elif a in berry:
    print("berrry")
elif a in tropical:
    print("Tropical")
else:
    print("unknown")
# Out:
# Enter the fruit name: strawberry
# berrry

# %%
#11.  Scenario: Grade Evaluator
#Create a program that takes marks (0–100) and prints grade:
#<40: Fail
#40–59: Pass
#60–79: Good
#80–100: Excellent
m = int(input("Enter the marks in range 1-100:"))
if m < 40:
    print("Fail")
elif m < 60:
    print("Pass")
elif m < 80:
    print("Good")
elif m<=100:
    print("Excellent")
else:
    print("limit  exceeded")
# Out:
# Enter the marks in range 1-100: 123
# limit  exceeded

# %%
#senario: Lucky 7 Game
#Write a program that takes a number.
#If it’s divisible by 7, print "Lucky", else "Try Again
n = int(input("Enter the number:"))
if n % 7 == 0:
    print("Lucky")
else:
    print("Try again")
# Out:
# Enter the number: 50
# try again

# %%
#13.  Scenario: Even or Odd
#Create a program that checks if a number is even or odd.
a = int(input("Enter the number:"))
if a % 2 == 0:
    print("Even")
else:
    print("odd")
# Out:
# Enter the number: 3
# odd

# %%
#Take three inputs: operation ("multiply" or "divide") and two numbers.
#Perform the operation.
a = int(input("Enter the first number:"))
b = int(input("Enter the second number:"))
o = input("Enter the operation multiplication or division:")
if o == 'multiplication':
    print(a*b)
elif o == 'division':
    if a>b :
        print(a//b)
    elif a == 0 or b == 0:
        print("cannot divide with zero")
# Out:
# Enter the first number: 0
# Enter the second number: 2
# Enter the operation multiplication or division: division
# cannot divide with zero

# %%
#15.  Scenario: Simple Calculator
#Take two numbers and an operator (+, -, *, /)
#Perform the operation and print the result.
a = int(input("Enter the first number:"))
b = int(input("Enter the second number:"))
op = input("Select an operation among + , - , * , / ")
if op == '+':
    print(a+b)
elif op == '-':
    print(a-b)
elif op == '*':
    print(a*b)
elif op == '/':
    print(a/b)
else:
    print("invalid operation")
# Out:
# Enter the first number: 2
# Enter the second number: 2
# Select an operation among + , - , * , /  =
# invalid operation

# %%
#16.  Scenario: Max of Three
#Take three numbers and print the maximum.

a = list(input("Enter the numbers:"))
b = max(a)
print(b)
# Out:
# Enter the numbers: 5 1 3
# 5

# %%
#17.  Scenario: Letter Case Checker
#Input a single character.
#Check if it’s uppercase, lowercase, or not an alphabet.
a = input("Enter the charecter")
if a.isupper():
    print("Upper case")
elif a.islower():
    print("Lower case")
elif a != a.isalpha():
    print("not an alphabet")
# Out:
# Enter the charecter 3
# not an alphabet

# %%
#18.  Scenario: Guess the Word
#Create a program that compares a guessed word to a hidden word.
#If it matches → "Correct"
#Else → "Try Again"
a = input("Enter the word:")
g_word = "love"
if a == g_word:
    print("correct")
else:
    print("Try again")
# Out:
# Enter the word: love
# correct

# %%
#Input three sides of a triangle.
#Print the type:
#All equal ➞ Equilateral
#Two equal ➞ Isosceles
#All different ➞ Scalene

s1 = int(input("Enter the first side:"))
s2 = int(input(" Enter the second side:"))
s3 = int(input(" Enter the third side:"))
if s1==s2==s3:
    print("Equilatarel")
elif s1==s2 or s2==s3 or s3==s1:
    print("isoceles")
else:
    print("scalene")
# Out:
# Enter the first side: 1
#  Enter the second side: 2
#  Enter the third side: 3
# scalene

# %%
try:
    a=int(input("enter a number:"))
    print(10/a)
except ZeroDivisionError:
    print("you cannot divide by zero")
except exception as e:
    print("we dont know error")
c=10
d=19
print(c+d)
# Out:
# enter a number: 0
# you cannot divide by zero
# 29

# %%
try:
    a=int(input("enter a number:"))
    print(10/a)
except ZeroDivisionError:
    print("you cannot divide by zero")
except exception as e:
    print("we dont know error")
else:
    print("division worked perfectly")
finally:
    print("program finished running")
# Out:
# enter a number: 0
# you cannot divide by zero
# program finished running

# %%
#10,20,30-->60
#10,20,abc,30-->error
a=input("enetr numbers seperated by spaces:").split()
numbers=[]
for i in a:
    numbers.append(int(i))
print(numbers)
# Out:
# enetr numbers seperated by spaces: 1
# [1]

# %%
try:
   a=input("enetr numbers seperated by spaces:").split()
   numbers=[]
   for i in a:
       try:
           numbers.append(int(i))
       except ValueError:
           print(f"invalid value:{i}")
   total=sum(numbers)
except exception as e:
    print("unecpeted error:",e)
else:
    print("sum of valid numbers:",total)
finally:   
    print("processe completd")
# Out:
# enetr numbers seperated by spaces: 1 2 3 4 abc 5
# invalid value:abc
# sum of valid numbers: 15
# processe completd

# %% [markdown]
# # types of exceptions

# %%
#syntax error-->mistake in code
print("hello
#
# Out:
#   Cell In[9], line 2
#     print("hello
#           ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
#indetention error-->there is code indentation issue
def fun():
print('a')
# Out:
#   Cell In[10], line 3
#     print('a')
#     ^
# IndentationError: expected an indented block after function definition on line 2

# %%
#name error:whoch varible or function is not defined
print(p)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 #name error:whoch varible or function is not defined
# ----> 2 print(p)
#
# NameError: name 'p' is not defined

# %%
#type error--> it performs when there is an in appropriate type
a="hello"+5
print(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 #type error--> it performs when there is an in appropriate type
# ----> 2 a="hello"+5
#       3 print(a)
#
# TypeError: can only concatenate str (not "int") to str

# %%
#value error--->when a function recives an argument of the correct type but with in approproate tyep
num=int('abc')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 2
#       1 #value error--->when a function recives an argument of the correct type but with in approproate tyep
# ----> 2 num=int('abc')
#
# ValueError: invalid literal for int() with base 10: 'abc'

# %%
#index error :occurs when try to acess an index that is in out of range for list
a=[1,2,3]
print(a[4])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[14], line 3
#       1 #index error :occurs when try to acess an index that is in out of range for list
#       2 a=[1,2,3]
# ----> 3 print(a[4])
#
# IndexError: list index out of range

# %%
#key error happens when try to acess a key that does'nt present 
a={'a':2}
print(b['age'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 3
#       1 #key error happens when try to acess a key that does'nt present
#       2 a={'a':2}
# ----> 3 print(b['age'])
#
# NameError: name 'b' is not defined

# %%
#zero diviosor error:occcurs when we try to divide by zero
10/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[16], line 2
#       1 #zero diviosor error:occcurs when we try to divide by zero
# ----> 2 10/0
#
# ZeroDivisionError: division by zero

# %%
#attributeerror:attribute or method not found
"hello".append("!")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 2
#       1 #attributeerror:attribute or method not found
# ----> 2 "hello".append("!")
#
# AttributeError: 'str' object has no attribute 'append'

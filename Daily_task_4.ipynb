# %%
#1.Write a Python program to check whether a number is positive.
a = int(input("Enter the number:"))
if a >= 0:
    print("Positive")
# Out:
# Enter the number: 10
# Positive

# %%
# Write a Python program to check whether a number is even or odd.
a = int(input("Enter the number:"))
if a % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Enter the number: 7
# Odd

# %%
# Write a program that prints "Pass" if the marks are greater than or equal to 35.
a = int(input("Enter the number:"))
if a >= 35:
    print("Pass")
# Out:
# Enter the number: 40
# Pass

# %%
#Write a Python program to check if two numbers are equal.
a = int(input("Enter the first number:"))
b = int(input("Enter the second number:"))
if a == b:
    print("Same")
# Out:
# Enter the first number: 5
# Enter the second number: 5
# Same

# %%
#Write a program to check if a given character is uppercase.
a = input("Enter the charecter:")
if a.isupper():
    print("Uppercase")
# Out:
# Enter the charecter: ADS
# Uppercase

# %%
# Write a Python program to check if a number is a multiple of 5.
a = int(input("Enter the number:"))
if a % 5 == 0:
    print("number is a multiple of 5")
# Out:
# Enter the number: 25
# number is a multiple of 5

# %%
#Write a program to check whether a given temperature is above the boiling point (100°C)
a = int(input("Enter the number:"))
if a > 100:
    print(f"Temperature{a} is  above boiling point")
else:
    print(f"Temperatur {a} is below boiling point")
# Out:
# Enter the number: 101
# Temperature101 is  above boiling point

# %%
#Take two numbers as input and print the greater number.
a = int(input("Enter the first number:"))
b = int(input("Enter the second number:"))
if a>b:
    print(f"{a} is greater")
if b>a:
    print(f"{b} is greater")
# Out:
# Enter the first number: 1
# Enter the second number: 2
# 2 is greater

# %%
#Write a Python program to check if a number is between 1 and 10 (inclusive).
a = int(input("Enter the number:"))
if a in range(1 , 10):
    print(f" The number {a} is In range")
# Out:
# Enter the number: 4
#  The number 4 is In range

# %%
#Write a program to check whether a person is eligible to vote (age ≥ 18).
age  = int(input("Enter the number:"))
if a >= 18:
    print(f" The age {age} is eligible for vote")
else:
    print(f" The age {age} is not eligible for vote")
# Out:
# Enter the number: 19
#  The age 19 is not eligible for vote

# %%
#Three students — Aman, Ravi, and Sneha — scored 56, 74, and 68 marks respectively.
#Write a program to print who got the highest marks.
aman  = 56
ravi = 74
sneha = 68
if aman>ravi and aman >sneha:
    print("Aman is highest")
elif ravi>aman and ravi>sneha:
    print("Ravi is highest")
else:
    print("sneha is highest")
# Out:
# Ravi is highest

# %%
#You are given the ages of three people: 45, 22, and 67.
#Write a program to display who is the youngest among them.
a1 = 45
a2 = 22
a3 = 67
if a1<a2 and a1<a3:
    print(f" {a1} is youngest")
elif a2<a1 and a2<a3:
    print(f" {a2} is youngest")
else:
    print(f"{a3} is youngest")
# Out:
#  22 is youngest

# %%
#13. Take a user’s age and classify the person as:
age  = int(input("Enter the age"))
if age <= 12:
    print("CHILD")
elif age >=13 and age <= 19:
    print("TEENAGER")
elif age>=20 and age <= 60:
    print("ADULT")
else:
    print("SENIOR CITIZEN")
# Out:
# Enter the age 15
# TEENAGER

# %%
#14.
#A cricket match scoreboard shows:
#Team A = 248, Team B = 251.
#Write a program to display which team won the match.
Team_A = 248
Team_B = 251
if Team_A > Team_B:
    print("Team A won")
else:
    print("Team B won")
# Out:
# Team B won

# %%
#5.
#You are given the speeds (in km/h) of three racing cars:
#Car1 = 180, Car2 = 190, Car3 = 175.
#Write a program to find which car is the fastest.
car1 = 180
car2 = 190
car3 = 175
if car1>car2 and car1>car3:
    print(" Car1 is the fastest")
elif car2>car1 and car2>car3:
    print(" Car2 is the fastest")
else:
    print(" Car3 is the fastest")
# Out:
#  Car2 is the fastest

# %%
#16.
#Take a temperature value in Celsius and classify the day as:
#Above 35 → Hot Day
#Between 20 and 35 → Pleasant Day
#Below 20 → Cold Day
tem = int(input("Enter the temperature:"))
if tem > 35:
    print(" Hot Day")
elif tem <20:
    print("Cold Day")
else:
    print("Pleasant Day")
# Out:
# Enter the temperature: 30
# Pleasant Day

# %%
# Ask the user to enter their age and nationality.
#If age ≥ 18 and nationality is "Indian", print "Eligible to vote in India".
a = int(input("Enter the age:"))
b = input("Enter nationality:").lower()
if a >= 18:
    if b == 'indian':
        print("Eligible to vote in India")
else:
    print("Not eligible")
# Out:
# Enter the age: 20
# Enter nationality: indian
# Eligible to vote in India

# %%
#18.
#Given the attendance percentage of a student, print:
#"Allowed to write exam" if ≥ 75
#"Not allowed" otherwise
a = float(input("Enter the attendence"))
if a >= 75:
    print("Allowed to write exam ")
else:
    print("Not Allowed to write exam")
# Out:
# Enter the attendence 23
# Not Allowed to write exam

# %%
#Two friends participated in a quiz and scored 18 and 18 marks respectively.
#Write a program to check whether it’s a draw or if someone won.
person_1 = 18
person_2 = 18
if person_1 > person_2:
    print("person_1 Won")
elif person_2<person_1:
    print("person_2 Won")
else:
    print("It's A Draw")
# Out:
# It's A Draw

# %%
#Take a number as input and check whether it is positive, negative, or zero.
n = int(input("Enter the number:"))
if n > 0:
    print("Positive")
elif n < 0:
    print("Negattive")
else:
    print("Zero")
# Out:
# Enter the number: 0
# Zero

# %% [markdown]
# # file handling

# %%
a=open('file.txt','r') #open existing file for reading 
if a:
    print("file opend")
# Out:
# file opend

# %%
a2=open(r"C:\Users\vinod\OneDrive\Pictures\other_file.txt",'r') #open existing file for reading 
if a:
    print("file opend")
# Out:
# file opend

# %%
a=open('file.txt','r') #open existing file for reading 
if a:
    print("file opend")
# Out:
# file opend

# %%
with open('file.txt','w')as file:
    file.write("hello world")

# %%
#over writes new content with old content
with open('file.txt','w')as file:
    file.write("python is very easy")

# %%
file.close()

# %%
with open ('file.txt','r') as f:
    content=f.read()
    print(content)
# Out:
# python is very easy

# %%
file.close()

# %%
with open(r"C:\Users\vinod\OneDrive\Pictures\other_file.txt",'w') as other:
    other.write("python is very easy")

# %%
other.close()

# %%
file=open ('file.txt','a') #append a new text
file.write(". it is fastest growing language")
file.close()

# %%
with open ('file.txt','r') as f:
    content=f.read()
    print(content)
# Out:
# python is very easy. it is fastest growing language

# %%
file.close()

# %%
with open ('file.txt','r') as f:
    content=f.read(12)
    print(content)
# Out:
# python is ve

# %%
file=open ('file.txt','a') #append a new text
file.write("\ndevelepoed by gudio van russum\nit is interpeted language")
file.close()

# %%
with open ('file.txt','r') as f:
    content=f.read()
    print(content)
# Out:
# python is very easy. it is fastest growing language
# develepoed by gudio van russum
# it is interpeted language

# %%
file=open ('file.txt','r')
content1=file.readline()
print(content1)
content2=file.readline()
print(content2)
content3=file.readline()
print(content3)
# Out:
# python is very easy. it is fastest growing language
#
# develepoed by gudio van russum
#
# it is interpeted language

# %%
file=open ('file.txt','r')
content=file.readlines()
print(content)
# Out:
# ['python is very easy. it is fastest growing language\n', 'develepoed by gudio van russum\n', 'it is interpeted language']

# %%
#read()---> read the content
#read(n)---> read the n charecters 
#readline()--->read the one  line at a time

# %%
file=open("python_new_file.txt","x")
file.write("python is very easy\nIt is fastest growing language")
file.close()

# %%
with open ('python_new_file.txt','r') as f:
    content=f.read()
    print(content)
# Out:
# python is very easy
# It is fastest growing language

# %%
with open("data.jpg","rb") as file:
    data =file.read()
    print(f"file size:{len(data)} bytes")
# Out:
# file size:413962 bytes

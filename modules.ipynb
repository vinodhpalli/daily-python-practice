# %%
def add(a,b):
    result=a+b
    return result
print(add(2,3))
# Out:
# 5

# %% [markdown]
# if i  add function in one jupyter notebook,u can call it only in the same file.
# if you open the another jupyter notebook that function won't exit there
# we put that function in python file(module)
# in the new file ,we need to call function by importing file

# %%
import my_module
print(my_module.add(2,3))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import my_module
#       2 print(my_module.add(2,3))
#
# ModuleNotFoundError: No module named 'my_module'

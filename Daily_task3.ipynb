# %% [markdown]
# ##  1. ARITHMETIC OPERATORS with Mixed operators

# %%
#John has 6 apples and 7 bananas. How many fruits does John have?
apples = 6
bananas = 7
print("Total fruits are:" , apples+bananas)
# Out:
# Total fruits are: 13

# %%
# Emma read 15 pages yesterday and 10 pages today. Did she read more than 20 pages in total?
yesterday = 15 # pages
today = 10 # pages
totat_read = yesterday + today
total = 20
print("Did she read 20 pages : ", totat_read >= total )
# Out:
# Did she read 20 pages :  True

# %%
#Mike had 30 candies an d gave 12 to his friend. How many does he have now? 
candies = 30
gave = 12
print("Remaining candies :" , candies - gave)
# Out:
# Remaining candies : 18

# %%
#Sarah bought 5 pens at $3 each. How much did she spend?
pens = 5 
each = 3
print("Total amount spent is : " , pens * each,'$')
# Out:
# Total amount spent is :  15 $

# %%
#There are 45 cookies equally divided among 5 kids. How many does each get? 
total = 45
kids  = 5
print("Each kid got:" , total//kids)
# Out:
# Each kid got: 9

# %%
#. A chocolate costs $2. You have $9. Can you buy 5 chocolates?
chocolat = 2
you_have = 9
print(" can i buy 5 choclates :" , you_have == 2*5)
# Out:
#  can i buy 5 choclates : False

# %%
#Peter has 5 books, each weighing 1.2 kg. Is the total weight more than 6 kg?
books = 5
weight = 1.2
print("does total weight more than 6 :" , 6 == books*weight)
# Out:
# does total weight more than 6 : True

# %%
#A movie ticket costs $12. Can you buy 4 with $50?
ticket = 12 
to_buy = 4
print(" can i buy 4 with 50:" , ticket == to_buy* 12)
# Out:
#  can i buy 4 with 50: False

# %%
#is the difference between 100 and 37 greater than 60?
difference = 100 - 37
print(" does difference greater than 60:" , difference>60)
# Out:
#  does difference greater than 60: True

# %%
#Does dividing 81 by 9 result in a number greater than 8?
r = 81//9
print("the number greater than 8:" , r>8)
# Out:
# the number greater than 8: True

# %%
#Are 5 multiplied by 6 and 30 equal?
print("Are 5 multiplied by 6 and 30 equal:" , 5*6 == 5*30)
# Out:
# Are 5 multiplied by 6 and 30 equal: False

# %%
#A basket holds 18 apples. If you eat 6, do you have fewer than 15 left?
total = 18
eat  = 6
print("do you have fewer than 15 left:" , total - eat < 15)
# Out:
# do you have fewer than 15 left: True

# %%
#Sam travels 120 km in 2 hours. Is his speed 60 km/hr?
speed = 120//2
print("Is his speed 60 km/hr:" , speed == 60)
# Out:
# Is his speed 60 km/hr: True

# %%
#Is 7 + 3 * 2 equal to 20?
print("Is 7 + 3 * 2 equal to 20 : " , 7+3 *2 == 20)
# Out:
# Is 7 + 3 * 2 equal to 20 :  False

# %%
#Jane bought 2 pens and 3 pencils. If a pen is $2 and pencil $1, did she spend $9?
pens = 2
pencils = 3
print("did she spend $9:" , pens *2 + pencils*1 == 9)
# Out:
# did she spend $9: False

# %%
# You have 3 boxes, each holding 12 balls. Are total balls more than 35?
print("Are total balls more than 35:" , 3 * 12 > 35)
# Out:
# Are total balls more than 35: True

# %%
#Does subtracting 20 from 50 give 30?
print("subtracting 20 from 50 give 30:" , 50 - 20 == 30)
# Out:
# subtracting 20 from 50 give 30: True

# %%
# Are 10 + 15 and 5 * 5 equal?
print("Are 10 + 15 and 5 * 5 equal:" , 10 + 15 == 5*5)
# Out:
# Are 10 + 15 and 5 * 5 equal: True

# %%
#If a packet has 48 candies, can 6 kids get more than 7 each?
print("can 6 kids get more than 7 each:" , 48 // 6 > 7)
# Out:
# can 6 kids get more than 7 each: True

# %%
#Multiply 4 by 4. Is the result less than 20
print("Is the result less than 20:" , 4 * 4 < 20)
# Out:
# Is the result less than 20: True

# %%
#Add 13 and 7. Is the result divisible by 5?
result = 13+7
print("Is the result divisible by 5:" , result % 5 ==0)
# Out:
# Is the result divisible by 5: True

# %%
#20 apples are equally shared between 5 students. Does each get 4
print(" Does each get 4 :" , 20 // 5 == 4)
# Out:
#  Does each get 4 : True

# %%
# Subtract 15 from 60. Is the result equal to 45?
print(" Is the result equal to 45:" , 60 - 15 == 45)
# Out:
#  Is the result equal to 45: True

# %%
#If you double 12, is the result more than 25?
print("is the result more than 25:" , 12*2 > 25)
# Out:
# is the result more than 25: False

# %%
#Are 100 divided by 4 and 25 equal?
print("Are 100 divided by 4 and 25 equal:" , 100 // 4 == 25)
# Out:
# Are 100 divided by 4 and 25 equal: True

# %%
#Add 5.5 and 4.5. Is the result 10?
print("Is the result 10:" , 5.5 + 4.5 == 10)
# Out:
# Is the result 10: True

# %%
#A number is 25. If you divide it by 4 using floor division, is the result 6
print("is the result 6 :" , 25 // 4 == 6)
# Out:
# is the result 6 : True

# %%
#What is the remainder when 29 is divided by 5? Is it equal to 4
print("Is it equal to 4 :" , 29  % 5 == 4)
# Out:
# Is it equal to 4 : True

# %%
#Is 3 ** 4 equal to 81?
print("Is 3 ** 4 equal to 81:" , 3 ** 4 == 81)
# Out:
# Is 3 ** 4 equal to 81: True

# %% [markdown]
# ## 2. COMPARISON OPERATORS with Mixed operators

# %%
# A bag contains 12 red balls and 8 blue balls. Is red > blue?
red = 12
blue = 8
print("Is red > blue:" , red > blue)
# Out:
# Is red > blue: True

# %%
#Q31. Tom scored 89 in math and 76 in science. Did he score more than 160 in total
math = 89
science  = 76
print(" Did he score more than 160 in total:" , math + science > 160)
# Out:
#  Did he score more than 160 in total: True

# %%
#Q32. A store sells apples at $2.50 each. If you buy 4, is the total cost more than $10
apple = 2.50
print("is the total cost more than $10:" , apple * 4 > 10)
# Out:
# is the total cost more than $10: False

# %%
#Q33. Alice has $100 and buys 3 books for $25 each. Will she have money left
money = 100
spent = 25 * 3
print("Will she have money left:" , money - spent != 0 )
# Out:
# Will she have money left: True

# %%
#A rectangle has length 10 and width 4. Is area greater than perimeter?
area = 10*4
perimeter = 2 * 10 + 4
print(" Is area greater than perimeter:" , area > perimeter)
# Out:
#  Is area greater than perimeter: True

# %%
#Two friends have 45 and 55 marbles. Do they have equal marbles
print(" Do they have equal marbles:" , 45 == 55)
# Out:
#  Do they have equal marbles: False

# %%
# A car travels 60 km/hr and a bike 40 km/hr. Is the car faster
print("Is the car faster:" , 60 > 40)
# Out:
# Is the car faster: True

# %%
#Two numbers are 13 and 17. Is their sum an even number
sum = 13+17
print("Is their sum an even number:" , sum %2 == 0)
# Out:
# Is their sum an even number: True

# %%
#A triangle has sides 3, 4, 5. Is it right-angled
# right angled triange = sum of squares of two sides  == square of laregr side
print("Is it right-angled:" , 3**2 + 4**2 == 5**2)
# Out:
# Is it right-angled: True

# %%
#Jenny had $50, bought items worth $35. Does she have less than $20 left
print("Does she have less than $20 left:" , 50 - 35 < 20 )
# Out:
# Does she have less than $20 left: True

# %%
#A worker earns $80 per day. Is 6 days' earning more than $500
print("Is 6 days' earning more than $500:" , 80 * 6 > 500)
# Out:
# Is 6 days' earning more than $500: False

# %%
#If a bottle contains 750 ml, do 4 bottles hold more than 3 liters
holds = 750  * 4
print("do 4 bottles hold more than 3 liters:" , holds > 3000)
# Out:
# do 4 bottles hold more than 3 liters: False

# %%
#Do two squares of side 4 and 5 have the same area?
a1 = 4 * 2
a2 = 5 * 2
print("Do two squares of side 4 and 5 have the same area:" , a1 == a2)
# Out:
# Do two squares of side 4 and 5 have the same area: False

# %%
#A triangle has angles 60, 60, 60. Do they sum to 180
sum  = 60 + 60 + 60
print("A triangle has angles 60, 60, 60. Do they sum to 180:" , sum == 180)
# Out:
# A triangle has angles 60, 60, 60. Do they sum to 180: True

# %%
# If you split 100 into two equal parts, is one part greater than 60
split = 100//2
print(" If you split 100 into two equal parts, is one part greater than 60 :" , split > 60)
# Out:
#  If you split 100 into two equal parts, is one part greater than 60 : False

# %%
#Mike earned $400 in 8 days. Did he earn $50 daily
day_1 = 400//8
print("Did he earn $50 daily:" , day_1 == 50)
# Out:
# Did he earn $50 daily: True

# %%
#Compare 5 ** 2 and 25. Are they equal
print("Compare 5 ** 2 and 25. Are they equal:"  , 5**2 == 25)
# Out:
# Compare 5 ** 2 and 25. Are they equal: True

# %%
#Is (10 + 2) * 3 greater than 35
print("Is (10 + 2) * 3 greater than 35:" , 10+2 > 35)
# Out:
# Is (10 + 2) * 3 greater than 35: False

# %%
#Do 8 and 8.0 compare equal
print("Do 8 and 8.0 compare equal:" , 8 == 8.0)
# Out:
# Do 8 and 8.0 compare equal: True

# %% [markdown]
# ## 3. LOGICAL OPERATORS

# %%
#Given a = 10 and b = 5, is (a > 5 and b < 10) True ?
a =10 
b =5
print(a > 5 and b < 10)
# Out:
# True

# %%
#if x = 8, is not (x > 10) True?
x = 8
print(not x > 10)
# Out:
# True

# %%
#Is (5 < 3 or 7 == 7) True?
print(5 < 3 or 7 == 7)
# Out:
# True

# %% [markdown]
# ## 4. ASSIGNMENT OPERATORS

# %%
# If x = 10 and x += 5, is new x equal to 15?
x =10
x+= 5
print(x == 15)
# Out:
# True

# %%
#If y = 20 and y -= 7, is the result less than 15
y = 20
y-= 7
print(y < 15)
# Out:
# True

# %%
#Given x = 12 and x *= 2, is x equal to 24
x = 12
x*= 2
print(x == 24)
# Out:
# True

# %% [markdown]
# ## 5. BITWISE OPERATORS

# %%
#If a = 6 and b = 3, is a & b equal to 2
a =6
b =3
print(a and b == 2)
# Out:
# False

# %%
#If a = 6 and b = 3, is a | b equal to 7?
a = 6
b = 3
print(a | b == 7)
# Out:
# True

# %%
# If a = 6 and b = 3, is a ^ b equal to 5?
a = 6
b = 3
print( a^b == 5)
# Out:
# True

# %%
# If a = 4, is ~a equal to −5
a = 4
print(~4 == -5)
# Out:
# True

# %%
#If a = 5, is a << 1 equal to 10
a = 5
print( a<<1 == 10)
# Out:
# True

# %%
#If a = 8, is a >> 2 equal to 2?
a = 8 
print(a>>2 == 2)
# Out:
# True
